# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.request
import os 

class new:
    def __init__(self,):
        pass
    
    def mkdir_(self,path):
        if not os.path.exists(path):
            os.makedirs(path)

    def news_crl(self,img_lim=10):
        url =  'https://www.ettoday.net/news/hot-news.htm'
        headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36'}

        res = requests.get(url , headers = headers)
        res.text
        soup = BeautifulSoup(res.text , 'html.parser')
        soup  #變成soup 就可以啟動找盒子的功能
        boxs = soup.find_all('div',class_='piece')  # piece clearfix
        # title    = boxs[2].find('img').get('title')
        # img_link = boxs[2].find('img').get('data-original')
        # print(title)
        # print(img_link)
        title_list =[]
        img_list = []
        for box in boxs:
            try:
                title    = box.find('img').get('title')
                if title == None:
                    break
                img_link = box.find('img').get('data-original')
                title_list.append(title)
                if len(title_list)==img_lim+1:
                    break
                img_list .append(img_link)
                print(title)
                print(img_link)
                print('======================================')
                time.sleep(0.01)
            except:
                break

        n=0   
        for link in img_list:
            L = 'https:'+ link
            urllib.request.urlretrieve(L,f'./0115/{n}.jpg')
            n=n+1

# %%
N=new()
N.mkdir_('./0115')
N.news_crl(20)
# Out:
# 下班去吃東西…名醫王群光過馬路被機車撞上！血流一地送醫不治
# //cdn2.ettoday.net/images/6571/c6571486.jpg
# ======================================
# 女女同婚配偶12天狂約7男！他「下身赤裸」暴斃摩鐵　手機揭惡行
# //cdn2.ettoday.net/images/6141/c6141179.jpg
# ======================================
# 浩子罕見火大當場變臉！一席話「改變國宴御廚」：你以為我在錄節目嗎
# //cdn2.ettoday.net/images/6570/c6570495.jpg
# ======================================
# 快訊／長沙大樓起火　整棟陷入火海黑煙狂竄！
# //cdn2.ettoday.net/images/6573/c6573415.jpg
# ======================================
# 保夾1980元！「娃娃機店夾到Coach」他開盒傻眼　警冷回：報警幹嘛
# //cdn2.ettoday.net/images/6572/c6572678.jpg
# ======================================
# 泰北高中數學師被資遣　「天天準時到校」122次...只為做一件事
# //cdn2.ettoday.net/images/5711/c5711582.jpg
# ======================================
# 黃鴻升走2年！守護他20年女人首曝光　Junior帶他生前最愛上陽明山
# //cdn2.ettoday.net/images/6572/c6572007.jpg
# ======================================
# 一堆人愛傳！訊息配上「1表情符號」爆反感　網轟：看了超不爽
# //cdn2.ettoday.net/images/5173/c5173351.jpg
# ======================================
# 小鬼黃鴻升離世2週年…　峮峮低調PO照「天空藏1符號」有洋蔥
# //cdn2.ettoday.net/images/6573/c6573420.jpg
# ======================================
# V吻額Jennie原圖瘋傳！緊貼彼此「同姿勢俏皮合照」　濟州島約會景點曝
# //cdn2.ettoday.net/images/6572/c6572157.jpg
# ======================================
# 保時捷電動車撞護欄引發大火　車門打不開！車主被活活燒死
# //cdn2.ettoday.net/images/6571/c6571829.jpg
# ======================================
# 金宇彬巴黎約會7年女友申敏兒！　「雙方全素顏」巧遇粉絲大方打招呼
# //cdn2.ettoday.net/images/6572/c6572120.jpg
# ======================================
# 重陽節要發錢了！10萬人受惠　住這縣市最高爽領9千元
# //cdn2.ettoday.net/images/6573/c6573280.jpg
# ======================================
# 驚揭罹癌…她手捧「瘀青豪乳」將切除：為了老婆孩子願跟大咪咪說掰
# //cdn2.ettoday.net/images/6572/c6572696.jpg
# ======================================
# 酷炫收到荷莉履歷！　提議拍「探討怎還活著」影片秒被封鎖傻眼了
# //cdn2.ettoday.net/images/6571/c6571884.jpg
# ======================================
# 好市多開賣人潮擠爆！iPhone 14系列「5款新機」價格曝　網直喊香
# //cdn2.ettoday.net/images/6572/c6572234.jpg
# ======================================
# 阿伯捷運上把玩「巨型玩具」！內行全看傻：明顯是個狠人
# //cdn2.ettoday.net/images/6571/c6571678.jpg
# ======================================
# 撞擊瞬間曝光！名醫王群光「紅燈過馬路」　遭機車猛撞送醫不治
# //cdn2.ettoday.net/images/6572/c6572499.jpg
# ======================================
# Angelababy抽菸片瘋傳...店家認了「員工偷拍」道歉！　陸網反應一面倒
# //cdn2.ettoday.net/images/6571/c6571706.jpg
# ======================================
# iPhone14 Pro機王現身「開機螢幕黑一片」　果粉妹崩潰：衰啊
# //cdn2.ettoday.net/images/6572/c6572385.jpg
# ======================================
